# %%
# !pip install ddgs
# Out:
# Collecting ddgs
#   Downloading ddgs-9.10.0-py3-none-any.whl.metadata (12 kB)
# Collecting click>=8.1.8 (from ddgs)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting primp>=0.15.0 (from ddgs)
#   Using cached primp-0.15.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting lxml>=4.9.4 (from ddgs)
#   Using cached lxml-6.0.2-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: httpx>=0.28.1 in ./env/lib/python3.12/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.28.1)
# Collecting fake-useragent>=2.2.0 (from ddgs)
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio in ./env/lib/python3.12/site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.12.1)
# Requirement already satisfied: certifi in ./env/lib/python3.12/site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in ./env/lib/python3.12/site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.9)
# Requirement already satisfied: idna in ./env/lib/python3.12/site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.11)
# Requirement already satisfied: h11>=0.16 in ./env/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.16.0)
# Collecting brotli (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Using cached brotli-1.2.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.1 kB)
# Collecting h2<5,>=3 (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting socksio==1.* (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading socksio-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing_extensions>=4.5 in ./env/lib/python3.12/site-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.15.0)
# Downloading ddgs-9.10.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.3 MB/s eta 0:00:00
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 7.1 MB/s eta 0:00:00
# Downloading socksio-1.0.0-py3-none-any.whl (12 kB)
# Using cached lxml-6.0.2-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (5.3 MB)
# Using cached primp-0.15.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 kB 5.7 MB/s eta 0:00:00
# Using cached brotli-1.2.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Installing collected packages: brotli, socksio, primp, lxml, hyperframe, hpack, fake-useragent, click, h2, ddgs
# Successfully installed brotli-1.2.0 click-8.3.1 ddgs-9.10.0 fake-useragent-2.2.0 h2-4.3.0 hpack-4.1.0 hyperframe-6.1.0 lxml-6.0.2 primp-0.15.0 socksio-1.0.0

# %%
pip install numpy
# Out:
# Collecting numpy
#   Using cached numpy-2.4.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Using cached numpy-2.4.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
# Installing collected packages: numpy
# Successfully installed numpy-2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel

agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=InferenceClientModel())

agent.run("Search for the best music recommendations for a party at the Wayne's mansion.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for the best music recommendations for a party at the Wayne's mansion.                                   │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="best music recommendations for a mansion party")
#   print(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Election Night Party Ideas - Mansion
# Global](https://www.mansionglobal.com/boutique/articles/prepare-for-your-election-night-gathering-like-a-diplomat-b
# 3b9c4a0)
# I remember helping make balls of butter for elaborate dinner parties , putting out silver, arranging flowers,
# fluffing pillows.
#
# [Wedding Party Entrance Songs to Get the Party Started -
# The](https://mansiononmainstreet.com/wedding-party-entrance-songs-to-get-the-party-started/)
# No matter what vibe you’re going for , there are some wedding party entrance songs that are guaranteed to be a hit
# with people.
#
# [Upbeat Last Dance Wedding Songs - The Mansion - Wedding
# Event](https://mansiononmainstreet.com/upbeat-last-dance-wedding-songs/)
# After exploring wedding dress, accessory, and beauty trends for 2025, it's time to focus on a detail that makes all
# the difference in a bride’s ...
#
# [Planning Wedding Music - Lone Star Mansion](https://lonestarmansion.com/blog/how-to-choose-wedding-music/)
# We’ve put together a few basic steps to help make choosing wedding music easier and have even put in some popular
# song recommendations to get you ...
#
# [Mansion at Mountain Lakes - Elegant Music Group](https://elegantmusicgroup.com/venues/mansion-at-mountain-lakes/)
# We felt that the music really would set the tone for the entire night and we wanted to make sure our guests felt
# that way too.
#
# [Wednesday Selection: Must-Listen New Music For Indie Pop
# Lovers](https://pophits.news/article/wednesday-selection-must-listen-new-music-for-indie-pop-lovers/)
# ... recommend checking out this song if you ’ re looking for something different and modern or have been wanting to
# try out something new in your ...
#
# [Include Music in Your Dinner Party Ideas — Magnolia
# Jazz](https://magnoliajazz.com/include-music-in-your-dinner-party-ideas)
# You’ll receive daily tips for planning wedding and party music , and you’ll get reminders for our public events.
#
# [Mansions | Enough Talk, More Writing!](https://trickaduu.com/tag/mansions/)
# And then it ’ s not good enough for their celeb standards … Meh, I ’ ve seen better. ... Must admit I ’ m looking
# forward ...
#
# [Rathbone Mansions - Live Music is Back!](https://rathbonemansions.com/new-blog/2021/3/18/live-music-is-back)
# Bacchanal - seating up to 6 people in a party they have a lovely outdoor patio with heat lamps featuring live music
# for dinner and brunch.
#
# [House Music Archives - Page 8 of 22 - Justin Levine](https://www.justindlevine.com/tag/house-music/page/8/)
# Don ’ t wait until the last minute to buy tickets for Knife Party on Sunday, September 1st at Mansion Nightclub
# during Labor Day Weekend! To ...
#
# Out: None
# [Step 1: Duration 29.27 seconds| Input tokens: 2,090 | Output tokens: 5,498]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("Jazz")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Jazz
# [Step 2: Duration 37.47 seconds| Input tokens: 4,968 | Output tokens: 13,174]
# 'Jazz'

# %%
# !pip install 'smolagents[litellm]'
# Out:
# Requirement already satisfied: smolagents[litellm] in ./env/lib/python3.12/site-packages (1.24.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.31.2 in ./env/lib/python3.12/site-packages (from smolagents[litellm]) (0.36.0)
# Requirement already satisfied: requests>=2.32.3 in ./env/lib/python3.12/site-packages (from smolagents[litellm]) (2.32.5)
# Requirement already satisfied: rich>=13.9.4 in ./env/lib/python3.12/site-packages (from smolagents[litellm]) (14.3.1)
# Requirement already satisfied: jinja2>=3.1.4 in ./env/lib/python3.12/site-packages (from smolagents[litellm]) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in ./env/lib/python3.12/site-packages (from smolagents[litellm]) (12.1.0)
# Requirement already satisfied: python-dotenv in ./env/lib/python3.12/site-packages (from smolagents[litellm]) (1.2.1)
# Collecting litellm>=1.60.2 (from smolagents[litellm])
#   Using cached litellm-1.81.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: filelock in ./env/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in ./env/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (2026.1.0)
# Requirement already satisfied: packaging>=20.9 in ./env/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in ./env/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in ./env/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./env/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./env/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./env/lib/python3.12/site-packages (from jinja2>=3.1.4->smolagents[litellm]) (3.0.3)
# Collecting aiohttp>=3.10 (from litellm>=1.60.2->smolagents[litellm])
#   Using cached aiohttp-3.13.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: click in ./env/lib/python3.12/site-packages (from litellm>=1.60.2->smolagents[litellm]) (8.3.1)
# Collecting fastuuid>=0.13.0 (from litellm>=1.60.2->smolagents[litellm])
#   Using cached fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: httpx>=0.23.0 in ./env/lib/python3.12/site-packages (from litellm>=1.60.2->smolagents[litellm]) (0.28.1)
# Collecting importlib-metadata>=6.8.0 (from litellm>=1.60.2->smolagents[litellm])
#   Using cached importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in ./env/lib/python3.12/site-packages (from litellm>=1.60.2->smolagents[litellm]) (4.26.0)
# Requirement already satisfied: openai>=2.8.0 in ./env/lib/python3.12/site-packages (from litellm>=1.60.2->smolagents[litellm]) (2.16.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.0 in ./env/lib/python3.12/site-packages (from litellm>=1.60.2->smolagents[litellm]) (2.12.5)
# Collecting tiktoken>=0.7.0 (from litellm>=1.60.2->smolagents[litellm])
#   Using cached tiktoken-0.12.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.7 kB)
# Collecting tokenizers (from litellm>=1.60.2->smolagents[litellm])
#   Using cached tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./env/lib/python3.12/site-packages (from requests>=2.32.3->smolagents[litellm]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.12/site-packages (from requests>=2.32.3->smolagents[litellm]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.12/site-packages (from requests>=2.32.3->smolagents[litellm]) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.12/site-packages (from requests>=2.32.3->smolagents[litellm]) (2026.1.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./env/lib/python3.12/site-packages (from rich>=13.9.4->smolagents[litellm]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./env/lib/python3.12/site-packages (from rich>=13.9.4->smolagents[litellm]) (2.19.2)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm])
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm])
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in ./env/lib/python3.12/site-packages (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm]) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm])
#   Using cached frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm])
#   Using cached multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm])
#   Using cached propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp>=3.10->litellm>=1.60.2->smolagents[litellm])
#   Using cached yarl-1.22.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (75 kB)
# Requirement already satisfied: anyio in ./env/lib/python3.12/site-packages (from httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (4.12.1)
# Requirement already satisfied: httpcore==1.* in ./env/lib/python3.12/site-packages (from httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./env/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm>=1.60.2->smolagents[litellm]) (0.16.0)
# Collecting zipp>=3.20 (from importlib-metadata>=6.8.0->litellm>=1.60.2->smolagents[litellm])
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./env/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.60.2->smolagents[litellm]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./env/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.60.2->smolagents[litellm]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in ./env/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.60.2->smolagents[litellm]) (0.30.0)
# Requirement already satisfied: mdurl~=0.1 in ./env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents[litellm]) (0.1.2)
# Requirement already satisfied: distro<2,>=1.7.0 in ./env/lib/python3.12/site-packages (from openai>=2.8.0->litellm>=1.60.2->smolagents[litellm]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in ./env/lib/python3.12/site-packages (from openai>=2.8.0->litellm>=1.60.2->smolagents[litellm]) (0.12.0)
# Requirement already satisfied: sniffio in ./env/lib/python3.12/site-packages (from openai>=2.8.0->litellm>=1.60.2->smolagents[litellm]) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.5.0->litellm>=1.60.2->smolagents[litellm]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.5.0->litellm>=1.60.2->smolagents[litellm]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.5.0->litellm>=1.60.2->smolagents[litellm]) (0.4.2)
# Collecting regex>=2022.1.18 (from tiktoken>=0.7.0->litellm>=1.60.2->smolagents[litellm])
#   Using cached regex-2026.1.15-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Using cached litellm-1.81.4-py3-none-any.whl (11.9 MB)
# Using cached aiohttp-3.13.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
# Using cached fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (278 kB)
# Using cached importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Using cached tiktoken-0.12.0-cp312-cp312-manylinux_2_28_x86_64.whl (1.2 MB)
# Using cached tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (242 kB)
# Using cached multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
# Using cached propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (221 kB)
# Using cached regex-2026.1.15-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (803 kB)
# Using cached yarl-1.22.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (377 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: zipp, regex, propcache, multidict, frozenlist, fastuuid, aiohappyeyeballs, yarl, tiktoken, importlib-metadata, aiosignal, tokenizers, aiohttp, litellm
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 fastuuid-0.14.0 frozenlist-1.8.0 importlib-metadata-8.7.1 litellm-1.81.4 multidict-6.7.1 propcache-0.4.1 regex-2026.1.15 tiktoken-0.12.0 tokenizers-0.22.2 yarl-1.22.0 zipp-3.23.0

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool,  LiteLLMModel

lmodel = LiteLLMModel(
        model_id="ollama_chat/qwen2:7b",  # Or try other Ollama-supported models
        api_base="http://127.0.0.1:11434",  # Default Ollama local server
        num_ctx=8192,
    )
agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=lmodel)

agent.run("Search for the best music recommendations for a party at the Wayne's mansion.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for the best music recommendations for a party at the Wayne's mansion.                                   │
# │                                                                                                                 │
# ╰─ LiteLLMModel - ollama_chat/qwen2:7b ───────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# [Step 1: Duration 404.98 seconds]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 10
#       3 lmodel = LiteLLMModel(
#       4         model_id="ollama_chat/qwen2:7b",  # Or try other Ollama-supported models
#       5         api_base="http://127.0.0.1:11434",  # Default Ollama local server
#       6         num_ctx=8192,
#       7     )
#       8 agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=lmodel)
# ---> 10 agent.run("Search for the best music recommendations for a party at the Wayne's mansion.")
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/smolagents/agents.py:498, in MultiStepAgent.run(self, task, stream, reset, images, additional_args, max_steps, return_full_result)
#     495     return self._run_stream(task=self.task, max_steps=max_steps, images=images)
#     497 run_start_time = time.time()
# --> 498 steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     500 # Outputs are returned only at the end. We only look at the last step.
#     501 assert isinstance(steps[-1], FinalAnswerStep)
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/smolagents/agents.py:577, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     575 self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
#     576 try:
# --> 577     for output in self._step_stream(action_step):
#     578         # Yield all
#     579         yield output
#     581         if isinstance(output, ActionOutput) and output.is_final_answer:
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/smolagents/agents.py:1662, in CodeAgent._step_stream(self, memory_step)
#    1660     output_text = chat_message.content
#    1661 else:
# -> 1662     chat_message: ChatMessage = self.model.generate(
#    1663         input_messages,
#    1664         stop_sequences=stop_sequences,
#    1665         **additional_args,
#    1666     )
#    1667     memory_step.model_output_message = chat_message
#    1668     output_text = chat_message.content
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/smolagents/models.py:1287, in LiteLLMModel.generate(self, messages, stop_sequences, response_format, tools_to_call_from, **kwargs)
#    1274 completion_kwargs = self._prepare_completion_kwargs(
#    1275     messages=messages,
#    1276     stop_sequences=stop_sequences,
#    (...)   1284     **kwargs,
#    1285 )
#    1286 self._apply_rate_limit()
# -> 1287 response = self.retryer(self.client.completion, **completion_kwargs)
#    1289 if not response.choices:
#    1290     raise RuntimeError(
#    1291         f"Unexpected API response: model '{self.model_id}' returned no choices. "
#    1292         " This may indicate a possible API or upstream issue. "
#    1293         f"Response details: {response.model_dump()}"
#    1294     )
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/smolagents/utils.py:542, in Retrying.__call__(self, fn, *args, **kwargs)
#     540 for attempt_number in range(1, self.max_attempts + 1):
#     541     try:
# --> 542         result = fn(*args, **kwargs)
#     544         # Log after successful call if we had retries
#     545         if self.after_logger and attempt_number > 1:
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/litellm/utils.py:1561, in client.<locals>.wrapper(*args, **kwargs)
#    1559         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1560 # MODEL CALL
# -> 1561 result = original_function(*args, **kwargs)
#    1562 end_time = datetime.datetime.now()
#    1563 if _is_streaming_request(
#    1564     kwargs=kwargs,
#    1565     call_type=call_type,
#    1566 ):
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/litellm/main.py:3834, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3831     if api_key is not None and "Authorization" not in headers:
#    3832         headers["Authorization"] = f"Bearer {api_key}"
# -> 3834     response = base_llm_http_handler.completion(
#    3835         model=model,
#    3836         stream=stream,
#    3837         messages=messages,
#    3838         acompletion=acompletion,
#    3839         api_base=api_base,
#    3840         model_response=model_response,
#    3841         optional_params=optional_params,
#    3842         litellm_params=litellm_params,
#    3843         shared_session=shared_session,
#    3844         custom_llm_provider="ollama_chat",
#    3845         timeout=timeout,
#    3846         headers=headers,
#    3847         encoding=_get_encoding(),
#    3848         api_key=api_key,
#    3849         logging_obj=logging,  # model call logging done inside the class as we make need to modify I/O to fit aleph alpha's requirements
#    3850         client=client,
#    3851     )
#    3853 elif custom_llm_provider == "triton":
#    3854     api_base = litellm.api_base or api_base
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:524, in BaseLLMHTTPHandler.completion(self, model, messages, api_base, custom_llm_provider, model_response, encoding, logging_obj, optional_params, timeout, litellm_params, acompletion, stream, fake_stream, api_key, headers, client, provider_config, shared_session)
#     521 else:
#     522     sync_httpx_client = client
# --> 524 response = self._make_common_sync_call(
#     525     sync_httpx_client=sync_httpx_client,
#     526     provider_config=provider_config,
#     527     api_base=api_base,
#     528     headers=headers,
#     529     data=data,
#     530     signed_json_body=signed_json_body,
#     531     timeout=timeout,
#     532     litellm_params=litellm_params,
#     533     logging_obj=logging_obj,
#     534 )
#     535 return provider_config.transform_response(
#     536     model=model,
#     537     raw_response=response,
#    (...)    546     json_mode=json_mode,
#     547 )
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:221, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     219 for i in range(max(max_retry_on_unprocessable_entity_error, 1)):
#     220     try:
# --> 221         response = sync_httpx_client.post(
#     222             url=api_base,
#     223             headers=headers,
#     224             data=(
#     225                 signed_json_body
#     226                 if signed_json_body is not None
#     227                 else json.dumps(data)
#     228             ),
#     229             timeout=timeout,
#     230             stream=stream,
#     231             logging_obj=logging_obj,
#     232         )
#     233     except httpx.HTTPStatusError as e:
#     234         hit_max_retry = i + 1 == max_retry_on_unprocessable_entity_error
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/litellm/llms/custom_httpx/http_handler.py:991, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     987 else:
#     988     req = self.client.build_request(
#     989         "POST", url, data=request_data, json=json, params=params, headers=headers, files=files, content=request_content  # type: ignore
#     990     )
# --> 991 response = self.client.send(req, stream=stream)
#     992 response.raise_for_status()
#     993 return response
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
from smolagents import CodeAgent, WebSearchTool, InferenceClientModel

agent = CodeAgent(tools=[WebSearchTool()], model=InferenceClientModel())

agent.run("Search for the best music recommendations for a party at the Wayne's mansion.")

# %%
from smolagents import CodeAgent, tool, InferenceClientModel

# Tool to suggest a menu based on the occasion
@tool
def suggest_menu(occasion: str) -> str:
    """
    Suggests a menu based on the occasion.
    Args:
        occasion (str): The type of occasion for the party. Allowed values are:
                        - "casual": Menu for casual party.
                        - "formal": Menu for formal party.
                        - "superhero": Menu for superhero party.
                        - "custom": Custom menu.
    """
    if occasion == "casual":
        return "Pizza, snacks, and drinks."
    elif occasion == "formal":
        return "3-course dinner with wine and dessert."
    elif occasion == "superhero":
        return "Buffet with high-energy and healthy food."
    else:
        return "Custom menu for the butler."

# Alfred, the butler, preparing the menu for the party
agent = CodeAgent(tools=[suggest_menu], model=InferenceClientModel())

# Preparing the menu for the party
agent.run("Prepare a casual menu for the party.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Prepare a casual menu for the party.                                                                            │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   menu = suggest_menu(occasion="casual")
#   final_answer(menu)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Pizza, snacks, and drinks.
# [Step 1: Duration 6.16 seconds| Input tokens: 2,112 | Output tokens: 945]
# 'Pizza, snacks, and drinks.'

# %%
from smolagents import CodeAgent, InferenceClientModel
import numpy as np
import time
import datetime

agent = CodeAgent(tools=[], model=InferenceClientModel(), additional_authorized_imports=['datetime'])

agent.run(
    """
    Alfred needs to prepare for the party. Here are the tasks:
    1. Prepare the drinks - 30 minutes
    2. Decorate the mansion - 60 minutes
    3. Set up the menu - 45 minutes
    4. Prepare the music and playlist - 45 minutes

    If we start right now, at what time will the party be ready?
    """
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Alfred needs to prepare for the party. Here are the tasks:                                                      │
# │     1. Prepare the drinks - 30 minutes                                                                          │
# │     2. Decorate the mansion - 60 minutes                                                                        │
# │     3. Set up the menu - 45 minutes                                                                             │
# │     4. Prepare the music and playlist - 45 minutes                                                              │
# │                                                                                                                 │
# │     If we start right now, at what time will the party be ready?                                                │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   total_minutes = 30 + 60 + 45 + 45
#   hours = total_minutes // 60
#   final_answer(f"{hours} hours from now")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 3 hours from now
# [Step 1: Duration 21.81 seconds| Input tokens: 2,111 | Output tokens: 3,352]
# '3 hours from now'

# %%
# !pip install markdownify requests
# Out:
# Collecting markdownify
#   Using cached markdownify-1.2.2-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: requests in ./env/lib/python3.12/site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in ./env/lib/python3.12/site-packages (from markdownify) (4.14.3)
# Requirement already satisfied: six<2,>=1.15 in ./env/lib/python3.12/site-packages (from markdownify) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./env/lib/python3.12/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.12/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.12/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.12/site-packages (from requests) (2026.1.4)
# Requirement already satisfied: soupsieve>=1.6.1 in ./env/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./env/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify) (4.15.0)
# Using cached markdownify-1.2.2-py3-none-any.whl (15 kB)
# Installing collected packages: markdownify
# Successfully installed markdownify-1.2.2

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel, VisitWebpageTool, FinalAnswerTool, Tool, tool

@tool
def suggest_menu(occasion: str) -> str:
    """
    Suggests a menu based on the occasion.
    Args:
        occasion: The type of occasion for the party.
    """
    if occasion == "casual":
        return "Pizza, snacks, and drinks."
    elif occasion == "formal":
        return "3-course dinner with wine and dessert."
    elif occasion == "superhero":
        return "Buffet with high-energy and healthy food."
    else:
        return "Custom menu for the butler."

@tool
def catering_service_tool(query: str) -> str:
    """
    This tool returns the highest-rated catering service in Gotham City.

    Args:
        query: A search term for finding catering services.
    """
    # Example list of catering services and their ratings
    services = {
        "Gotham Catering Co.": 4.9,
        "Wayne Manor Catering": 4.8,
        "Gotham City Events": 4.7,
    }

    # Find the highest rated catering service (simulating search query filtering)
    best_service = max(services, key=services.get)

    return best_service

class SuperheroPartyThemeTool(Tool):
    name = "superhero_party_theme_generator"
    description = """
    This tool suggests creative superhero-themed party ideas based on a category.
    It returns a unique party theme idea."""

    inputs = {
        "category": {
            "type": "string",
            "description": "The type of superhero party (e.g., 'classic heroes', 'villain masquerade', 'futuristic gotham').",
        }
    }

    output_type = "string"

    def forward(self, category: str):
        themes = {
            "classic heroes": "Justice League Gala: Guests come dressed as their favorite DC heroes with themed cocktails like 'The Kryptonite Punch'.",
            "villain masquerade": "Gotham Rogues' Ball: A mysterious masquerade where guests dress as classic Batman villains.",
            "futuristic gotham": "Neo-Gotham Night: A cyberpunk-style party inspired by Batman Beyond, with neon decorations and futuristic gadgets."
        }

        return themes.get(category.lower(), "Themed party idea not found. Try 'classic heroes', 'villain masquerade', or 'futuristic gotham'.")


# Alfred, the butler, preparing the menu for the party
agent = CodeAgent(
    tools=[
        DuckDuckGoSearchTool(),
        VisitWebpageTool(),
        suggest_menu,
        catering_service_tool,
        SuperheroPartyThemeTool()
        ],
    model=InferenceClientModel(),
    max_steps=10,
    verbosity_level=2
)

agent.run("Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme        │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: I need to find a playlist for a villain masquerade party at Wayne's mansion. Since the theme is
# villain-focused, I'll use web_search to find the best playlist recommendations for such a theme.
#
# <code>
# search_results = web_search(query="best villain masquerade party playlist")
# print(search_results)
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="best villain masquerade party playlist")
#   print(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [92 Halloween Monster Villain Masquerade Party ideas | masquerade
# ...](https://www.pinterest.com/moiragleen/halloween-monster-villain-masquerade-party/)
# Pin by Moira Gleen on Halloween Monster Villain Masquerade Party | Halloween monster, Masquerade party , Masquerade
# .Elegant Halloween Party Masquerade Mask. Halloween Kitchen Island Centerpiece. Black Cabinet Halloween Theme.
#
# [Masquerade - Masquerade - Villain | Spinnin'
# Records](https://spinninrecords.com/talentpool/artist/masquerade/track/2022-04-masquerade-villain)
# Dashboard F.A.Q. Terms of use. Masquerade - Villain .Been working on some new stuff, and trying new stuff. So here
# something new. I'm also working on the vocals but I'm saving up some money for better vocal processing plugins.
#
# [Masquerade party playlist | Кидаем песни, которые вы хотели бы...](https://vk.com/da_epta)
# Masquerade party playlist . Участники 12. Андрей Шабанов. Masquerade party playlistКидаем песни, которые вы хотели
# бы услышать на новогодней дискотеке.
#
# [DISNEY DESIGNER MIDNIGHT MASQUERADE VILLAIN ... - YouTube](https://www.youtube.com/watch?v=_sWMRoM5Sy4)
# Include playlist . An error occurred while retrieving sharing information.
#
# [Villainous Villainess Masquerade (Otomemob) |
# SpaceBattles](https://forums.spacebattles.com/threads/villainous-villainess-masquerade-otomemob.1170960/)
# Villainous Villainess Masquerade (Otomemob). Thread starter Worldbringer of Joseun. Start date Jun 22, 2024.Very
# well formed and shapely underneath those skirts, and better yet, it gently led to a narrow waist that Leon could
# wrap his hands around. He could regard that waist for hours.
#
# [Disney Villains Midnight Masquerade Doll and... | the disney food
# blog](https://www.disneyfoodblog.com/2020/09/25/disney-villains-midnight-masquerade-doll-and-pin-collection-to-rele
# ase-online-with-merchpass/)
# Lady Tremaine Midnight Masquerade Doll and Pins ©Disney. Call her the Sea Hag or call her by her name, Ursula, but
# she’s still the baddest witch at the bottom of the sea.
#
# [Limited Edition Disney Villains Designer Collection... -
# YouLoveIt.com](https://www.youloveit.com/dolls/1483-limited-edition-disney-designer-collection-midnight-masquerade-
# 2020-dolls-series-2-with-villains.html)
# Disney Villains Designer Midnight Masquerade Maleficent doll box. Will they never learn? Uninvited guests have a
# habit of inviting trouble.
#
# [The 12 Best Female Villains From The MHA
# Universe](https://www.cbr.com/my-hero-academia-best-female-villains-ranked/)
# My Hero Academia and MHA: Vigilantes feature some menacing and engaging female villains that help put them among
# the best manga available today.
#
# [HURRY! The Disney Villain Masquerade Collection... -
# AllEars.Net](https://allears.net/2020/11/10/hurry-the-disney-villain-masquerade-collection-featuring-hades-is-avail
# able-online/)
# Find the Hades Collectible Masquerade Doll on shopDisney here! Two limited-edition pins are available to order as
# well ! The first features Hades looking dastardly in his Masquerade cloak. The other features Pain and Panic in a
# style that resembles the dramatic art masks.
#
# [Masquerade | Villains Wiki | Fandom](https://villains.fandom.com/wiki/Masquerade)
# " Masquerade " may be referring to two or more different villains . If you're uncertain which one you're looking
# for, just flip a coin. If you came here from a link, please go back and make the right link for one of the villains
# listed below.
#
# Out: None
# [Step 1: Duration 14.94 seconds| Input tokens: 2,309 | Output tokens: 1,975]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: I need to compile a playlist of villain-themed songs suitable for a Wayne's mansion party with a villain
# masquerade theme. Based on the search results, Disney villain songs are highly relevant, along with classic villain
# tracks from other genres. I'll create a list of top songs from Disney movies and other iconic villain-themed
# tracks.
#
# <code>
# playlist = [
#     "Poor Unfortunate Souls - Ursula (The Little Mermaid)",
#     "Be Prepared - Scar (The Lion King)",
#     "Hellfire - Frollo (The Hunchback of Notre Dame)",
#     "Gaston - Gaston (Beauty and the Beast)",
#     "Mother Knows Best - Mother Gothel (Tangled)",
#     "Evil Woman - Black Sabbath",
#     "Sympathy for the Devil - The Rolling Stones",
#     "Bad Guy - Billie Eilish",
#     "Criminal - Fiona Apple",
#     "Villain - The Used",
#     "Poison - Alice Cooper",
#     "Joker - Steppenwolf",
#     "Gotham City - R. Kelly",
#     "The World Is Mine - Scar (Lion King Musical)",
#     "Masquerade - Villain - Masquerade"
# ]
# final_answer("Here's the ultimate villain masquerade party playlist for Wayne's mansion:\n" + "\n".join([f"{i+1}.
# {song}" for i, song in enumerate(playlist)]))
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   playlist = [
#       "Poor Unfortunate Souls - Ursula (The Little Mermaid)",
#       "Be Prepared - Scar (The Lion King)",
#       "Hellfire - Frollo (The Hunchback of Notre Dame)",
#       "Gaston - Gaston (Beauty and the Beast)",
#       "Mother Knows Best - Mother Gothel (Tangled)",
#       "Evil Woman - Black Sabbath",
#       "Sympathy for the Devil - The Rolling Stones",
#       "Bad Guy - Billie Eilish",
#       "Criminal - Fiona Apple",
#       "Villain - The Used",
#       "Poison - Alice Cooper",
#       "Joker - Steppenwolf",
#       "Gotham City - R. Kelly",
#       "The World Is Mine - Scar (Lion King Musical)",
#       "Masquerade - Villain - Masquerade"
#   ]
#   final_answer("Here's the ultimate villain masquerade party playlist for Wayne's mansion:\n" +
#   "\n".join([f"{i+1}. {song}" for i, song in enumerate(playlist)]))
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Here's the ultimate villain masquerade party playlist for Wayne's mansion:
# 1. Poor Unfortunate Souls - Ursula (The Little Mermaid)
# 2. Be Prepared - Scar (The Lion King)
# 3. Hellfire - Frollo (The Hunchback of Notre Dame)
# 4. Gaston - Gaston (Beauty and the Beast)
# 5. Mother Knows Best - Mother Gothel (Tangled)
# 6. Evil Woman - Black Sabbath
# 7. Sympathy for the Devil - The Rolling Stones
# 8. Bad Guy - Billie Eilish
# 9. Criminal - Fiona Apple
# 10. Villain - The Used
# 11. Poison - Alice Cooper
# 12. Joker - Steppenwolf
# 13. Gotham City - R. Kelly
# 14. The World Is Mine - Scar (Lion King Musical)
# 15. Masquerade - Villain - Masquerade
# [Step 2: Duration 26.31 seconds| Input tokens: 5,678 | Output tokens: 6,327]
# "Here's the ultimate villain masquerade party playlist for Wayne's mansion:\n1. Poor Unfortunate Souls - Ursula (The Little Mermaid)\n2. Be Prepared - Scar (The Lion King)\n3. Hellfire - Frollo (The Hunchback of Notre Dame)\n4. Gaston - Gaston (Beauty and the Beast)\n5. Mother Knows Best - Mother Gothel (Tangled)\n6. Evil Woman - Black Sabbath\n7. Sympathy for the Devil - The Rolling Stones\n8. Bad Guy - Billie Eilish\n9. Criminal - Fiona Apple\n10. Villain - The Used\n11. Poison - Alice Cooper\n12. Joker - Steppenwolf\n13. Gotham City - R. Kelly\n14. The World Is Mine - Scar (Lion King Musical)\n15. Masquerade - Villain - Masquerade"
