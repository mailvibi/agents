# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from smolagents import ToolCallingAgent, DuckDuckGoSearchTool, InferenceClientModel

model = InferenceClientModel(model_id="meta-llama/Llama-3.1-8B-Instruct")

agent = ToolCallingAgent(tools=[DuckDuckGoSearchTool()], model=model)

agent.run("Search for the best music recommendations for a party at the Wayne's mansion.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for the best music recommendations for a party at the Wayne's mansion.                                   │
# │                                                                                                                 │
# ╰─ InferenceClientModel - meta-llama/Llama-3.1-8B-Instruct ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Error while generating output:
# (Request ID: Root=1-697c91bd-36fef95842b0962c48165d4a;72012350-8fdc-4ef0-95bd-45eab20807f7)
#
# Bad request:
# [Step 1: Duration 0.51 seconds]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:402, in hf_raise_for_status(response, endpoint_name)
#     401 try:
# --> 402     response.raise_for_status()
#     403 except HTTPError as e:
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://router.huggingface.co/novita/v3/openai/chat/completions
#
# The above exception was the direct cause of the following exception:
#
# BadRequestError                           Traceback (most recent call last)
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/smolagents/agents.py:1293, in ToolCallingAgent._step_stream(self, memory_step)
#    1292 else:
# -> 1293     chat_message: ChatMessage = self.model.generate(
#    1294         input_messages,
#    1295         stop_sequences=["Observation:", "Calling tools:"],
#    1296         tools_to_call_from=self.tools_and_managed_agents,
#    1297     )
#    1298     self.logger.log_markdown(
#    1299         content=str(chat_message.content or chat_message.raw or ""),
#    1300         title="Output message of the LLM:",
#    1301         level=LogLevel.DEBUG,
#    1302     )
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/smolagents/models.py:1576, in InferenceClientModel.generate(self, messages, stop_sequences, response_format, tools_to_call_from, **kwargs)
#    1575 self._apply_rate_limit()
# -> 1576 response = self.retryer(self.client.chat_completion, **completion_kwargs)
#    1577 content = response.choices[0].message.content
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/smolagents/utils.py:542, in Retrying.__call__(self, fn, *args, **kwargs)
#     541 try:
# --> 542     result = fn(*args, **kwargs)
#     544     # Log after successful call if we had retries
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/huggingface_hub/inference/_client.py:915, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     908 request_parameters = provider_helper.prepare_request(
#     909     inputs=messages,
#     910     parameters=parameters,
#    (...)    913     api_key=self.token,
#     914 )
# --> 915 data = self._inner_post(request_parameters, stream=stream)
#     917 if stream:
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/huggingface_hub/inference/_client.py:275, in InferenceClient._inner_post(self, request_parameters, stream)
#     274 try:
# --> 275     hf_raise_for_status(response)
#     276     return response.iter_lines() if stream else response.content
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:458, in hf_raise_for_status(response, endpoint_name)
#     455     message = (
#     456         f"\n\nBad request for {endpoint_name} endpoint:" if endpoint_name is not None else "\n\nBad request:"
#     457     )
# --> 458     raise _format(BadRequestError, message, response) from e
#     460 elif response.status_code == 403:
#
# BadRequestError: (Request ID: Root=1-697c91bd-36fef95842b0962c48165d4a;72012350-8fdc-4ef0-95bd-45eab20807f7)
#
# Bad request:
#
# The above exception was the direct cause of the following exception:
#
# AgentGenerationError                      Traceback (most recent call last)
# Cell In[2], line 7
#       3 model = InferenceClientModel(model_id="meta-llama/Llama-3.1-8B-Instruct")
#       5 agent = ToolCallingAgent(tools=[DuckDuckGoSearchTool()], model=model)
# ----> 7 agent.run("Search for the best music recommendations for a party at the Wayne's mansion.")
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/smolagents/agents.py:498, in MultiStepAgent.run(self, task, stream, reset, images, additional_args, max_steps, return_full_result)
#     495     return self._run_stream(task=self.task, max_steps=max_steps, images=images)
#     497 run_start_time = time.time()
# --> 498 steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     500 # Outputs are returned only at the end. We only look at the last step.
#     501 assert isinstance(steps[-1], FinalAnswerStep)
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/smolagents/agents.py:595, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     591             action_step.is_final_answer = True
#     593 except AgentGenerationError as e:
#     594     # Agent generation errors are not caused by a Model error but an implementation error: so we should raise them and exit.
# --> 595     raise e
#     596 except AgentError as e:
#     597     # Other AgentError types are caused by the Model, so we should log them and iterate.
#     598     action_step.error = e
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/smolagents/agents.py:577, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     575 self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
#     576 try:
# --> 577     for output in self._step_stream(action_step):
#     578         # Yield all
#     579         yield output
#     581         if isinstance(output, ActionOutput) and output.is_final_answer:
#
# File ~/p/hf/smolagent/env/lib/python3.12/site-packages/smolagents/agents.py:1309, in ToolCallingAgent._step_stream(self, memory_step)
#    1307     memory_step.token_usage = chat_message.token_usage
#    1308 except Exception as e:
# -> 1309     raise AgentGenerationError(f"Error while generating output:\n{e}", self.logger) from e
#    1311 if chat_message.tool_calls is None or len(chat_message.tool_calls) == 0:
#    1312     try:
#
# AgentGenerationError: Error while generating output:
# (Request ID: Root=1-697c91bd-36fef95842b0962c48165d4a;72012350-8fdc-4ef0-95bd-45eab20807f7)
#
# Bad request:
