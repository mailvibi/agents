# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel

# Initialize the search tool
search_tool = DuckDuckGoSearchTool()

# Initialize the model
model = InferenceClientModel()

agent = CodeAgent(
    model=model,
    tools=[search_tool],
)

# Example usage
response = agent.run(
    "Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering."
)
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering.             │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="luxury superhero-themed party ideas decorations entertainment catering")
#   final_answer(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: ## Search Results
#
# [Antman Birthday Party Ideas](https://ru.pinterest.com/ideas/antman-birthday-party-ideas/915099409972/)
# Marvel Party Ideas Decoration .Hank's Superhero Birthday Party — Papillons Entertainment + Events. We planned our
# first superhero themed party for our buddy Jim Jefferies’ son Hank and the results were super cute, colorful, and
# classy.
#
# [Amazon.com: Oiuyamn 10 Pieces Hero Party Decoration , Hero
# ...](https://www.amazon.com/Oiuyamn-Decoration-Centerpieces-Decorations-Hero-Theme/dp/B0F91BG2QY)
# Multi-Use Decor : Perfect for hero birthday parties , comic- themed gatherings, school events, or superhero photo
# booths. Mix and match colors and designs for tables, walls, or DIY backdrops—indoor or outdoor.
#
# [5 Tips For Hosting A Themed Party | Incredible
# Things](https://incrediblethings.com/events/5-tips-for-hosting-a-themed-party/)
# Sometimes a regular party doesn't cut it. One great way to do this is by hosting a themed party .For instance, if
# you are hosting a superhero - themed party , you could get masks, capes, and even toy weapons for guests to use as
# props.
#
# [Korean Themed Debut Party - The Moment
# Style](https://ofthemomentstyle.blogspot.com/2021/10/korean-themed-debut-party.html)
# Super Hero Themed Party If you have always been an avid fan of DC or Marvel comics incorporate the superhero theme
# into your debut. Korean themed debut party . 142019 Some debutantes opt to have 18s consistent with their party
# theme .
#
# [Party Bag Kids, Frozen Door Banner](https://partybagkids.co.uk/frozen-party-disneys-frozen-penant-banner/)
# Party Bag Kids UK, Frozen themed piͱata, start your frozen themed party in style with this fabulous door banner
# featuring Anna and Elsa.
#
# [Italian Themed Party - The Glitzy Balloon Company](https://theglitzyballooncompany.co.uk/italian-themed-party/)
# Superhero Themed Party .Balloons are fantastic at filling a space and giving you that wow factor like no other form
# of decoration . It’s so eye-catching and a lot more cost-effective than a floral installation, balloons will still
# give your event added grace and style.
#
# [Is it Rude Not to Have Goody Bags at a Kid's Party
# ?](https://www.nonstopkids.co.uk/post/do-you-have-to-hand-out-kids-party-bags)
# Superhero Themed Party .Send them home with cake – Pop it in a napkin or box and hand it out at the door. Craft or
# activity take-home – If the kids make something at the party , that becomes the gift! Edible treats – Decorated
# biscuits or cupcakes are a crowd-pleaser.
#
# [etsy.com](https://etsy.com/)
# 10 Fun Christmas Party Games for Adults and Teens.
#
# [Секретка В Аватар World 2026 Аквапарк 5 6 7 12 |
# TikTok](https://www.tiktok.com/discover/секретка-в-аватар-world-2026-аквапарк-5-6-7-12)
# Explore the secrets of Avatar World, including baby room decor ideas and new house updates. Discover how to get
# free packs and unlock baby shower secrets. #avatarworld #avatarworldsecret #avatarworldupdate #pazu #babyrooms.
#
# [Construction de systèmes de RAG... - Hugging Face Agents
# Course](https://huggingface.co/learn/agents-course/fr/unit2/smolagents/retrieval_agents)
# Exemple d'utilisation response = agent.run( "Search for luxury superhero - themed party ideas , including
# decorations , entertainment , and catering ." )
# [Step 1: Duration 10.28 seconds| Input tokens: 2,091 | Output tokens: 1,582]
# ## Search Results
#
# [Antman Birthday Party Ideas](https://ru.pinterest.com/ideas/antman-birthday-party-ideas/915099409972/)
# Marvel Party Ideas Decoration .Hank's Superhero Birthday Party — Papillons Entertainment + Events. We planned our first superhero themed party for our buddy Jim Jefferies’ son Hank and the results were super cute, colorful, and classy.
#
# [Amazon.com: Oiuyamn 10 Pieces Hero Party Decoration , Hero ...](https://www.amazon.com/Oiuyamn-Decoration-Centerpieces-Decorations-Hero-Theme/dp/B0F91BG2QY)
# Multi-Use Decor : Perfect for hero birthday parties , comic- themed gatherings, school events, or superhero photo booths. Mix and match colors and designs for tables, walls, or DIY backdrops—indoor or outdoor.
#
# [5 Tips For Hosting A Themed Party | Incredible Things](https://incrediblethings.com/events/5-tips-for-hosting-a-themed-party/)
# Sometimes a regular party doesn't cut it. One great way to do this is by hosting a themed party .For instance, if you are hosting a superhero - themed party , you could get masks, capes, and even toy weapons for guests to use as props.
#
# [Korean Themed Debut Party - The Moment Style](https://ofthemomentstyle.blogspot.com/2021/10/korean-themed-debut-party.html)
# Super Hero Themed Party If you have always been an avid fan of DC or Marvel comics incorporate the superhero theme into your debut. Korean themed debut party . 142019 Some debutantes opt to have 18s consistent with their party theme .
#
# [Party Bag Kids, Frozen Door Banner](https://partybagkids.co.uk/frozen-party-disneys-frozen-penant-banner/)
# Party Bag Kids UK, Frozen themed piͱata, start your frozen themed party in style with this fabulous door banner featuring Anna and Elsa.
#
# [Italian Themed Party - The Glitzy Balloon Company](https://theglitzyballooncompany.co.uk/italian-themed-party/)
# Superhero Themed Party .Balloons are fantastic at filling a space and giving you that wow factor like no other form of decoration . It’s so eye-catching and a lot more cost-effective than a floral installation, balloons will still give your event added grace and style.
#
# [Is it Rude Not to Have Goody Bags at a Kid's Party ?](https://www.nonstopkids.co.uk/post/do-you-have-to-hand-out-kids-party-bags)
# Superhero Themed Party .Send them home with cake – Pop it in a napkin or box and hand it out at the door. Craft or activity take-home – If the kids make something at the party , that becomes the gift! Edible treats – Decorated biscuits or cupcakes are a crowd-pleaser.
#
# [etsy.com](https://etsy.com/)
# 10 Fun Christmas Party Games for Adults and Teens.
#
# [Секретка В Аватар World 2026 Аквапарк 5 6 7 12 | TikTok](https://www.tiktok.com/discover/секретка-в-аватар-world-2026-аквапарк-5-6-7-12)
# Explore the secrets of Avatar World, including baby room decor ideas and new house updates. Discover how to get free packs and unlock baby shower secrets. #avatarworld #avatarworldsecret #avatarworldupdate #pazu #babyrooms.
#
# [Construction de systèmes de RAG... - Hugging Face Agents Course](https://huggingface.co/learn/agents-course/fr/unit2/smolagents/retrieval_agents)
# Exemple d'utilisation response = agent.run( "Search for luxury superhero - themed party ideas , including decorations , entertainment , and catering ." )

# %%
# !pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-core<2.0.0,>=1.0.1 (from langchain_community)
#   Downloading langchain_core-1.2.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Downloading langchain_classic-1.0.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain_community)
#   Downloading sqlalchemy-2.0.46-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in ./env/lib/python3.12/site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in ./env/lib/python3.12/site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./env/lib/python3.12/site-packages (from langchain_community) (3.13.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain_community)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Downloading pydantic_settings-2.12.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting langsmith<1.0.0,>=0.1.125 (from langchain_community)
#   Downloading langsmith-0.6.6-py3-none-any.whl.metadata (15 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in ./env/lib/python3.12/site-packages (from langchain_community) (2.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in ./env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Downloading langchain_text_splitters-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./env/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.5)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.0.1->langchain_community)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting packaging<26.0.0,>=23.2.0 (from langchain-core<2.0.0,>=1.0.1->langchain_community)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./env/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.0.1->langchain_community)
#   Downloading uuid_utils-0.14.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.1.125->langchain_community)
#   Downloading orjson-3.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 7.5 MB/s eta 0:00:00
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.1.125->langchain_community)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.1.125->langchain_community)
#   Downloading zstandard-0.25.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./env/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./env/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./env/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2026.1.4)
# Collecting greenlet>=1 (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community)
#   Downloading greenlet-3.3.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: anyio in ./env/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.12.1)
# Requirement already satisfied: httpcore==1.* in ./env/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./env/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./env/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.5)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 7.0 MB/s eta 0:00:0000:0100:01
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 7.5 MB/s eta 0:00:00a 0:00:01
# Downloading langchain_core-1.2.7-py3-none-any.whl (490 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.2/490.2 kB 7.6 MB/s eta 0:00:00a 0:00:01
# Downloading langsmith-0.6.6-py3-none-any.whl (308 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.5/308.5 kB 6.1 MB/s eta 0:00:00a 0:00:01
# Downloading pydantic_settings-2.12.0-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 6.2 MB/s eta 0:00:00
# Downloading sqlalchemy-2.0.46-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 7.4 MB/s eta 0:00:0000:0100:01
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading greenlet-3.3.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (609 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.9/609.9 kB 7.2 MB/s eta 0:00:00a 0:00:01m
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 7.5 MB/s eta 0:00:00
# Downloading orjson-3.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.6/145.6 kB 7.7 MB/s eta 0:00:00
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.1 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading uuid_utils-0.14.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.0/342.0 kB 6.7 MB/s eta 0:00:00a 0:00:01
# Downloading zstandard-0.25.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 7.2 MB/s eta 0:00:0000:0100:01
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: zstandard, uuid-utils, tenacity, packaging, orjson, mypy-extensions, jsonpatch, httpx-sse, greenlet, typing-inspect, SQLAlchemy, requests-toolbelt, marshmallow, pydantic-settings, langsmith, dataclasses-json, langchain-core, langchain-text-splitters, langchain-classic, langchain_community
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.0
#     Uninstalling packaging-26.0:
#       Successfully uninstalled packaging-26.0
# Successfully installed SQLAlchemy-2.0.46 dataclasses-json-0.6.7 greenlet-3.3.1 httpx-sse-0.4.3 jsonpatch-1.33 langchain-classic-1.0.1 langchain-core-1.2.7 langchain-text-splitters-1.1.0 langchain_community-0.4.1 langsmith-0.6.6 marshmallow-3.26.2 mypy-extensions-1.1.0 orjson-3.11.6 packaging-25.0 pydantic-settings-2.12.0 requests-toolbelt-1.0.0 tenacity-9.1.2 typing-inspect-0.9.0 uuid-utils-0.14.0 zstandard-0.25.0

# %%
# !pip install rank_bm25
# Out:
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy in ./env/lib/python3.12/site-packages (from rank_bm25) (2.4.1)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Installing collected packages: rank_bm25
# Successfully installed rank_bm25-0.2.2

# %%
from langchain_community.docstore.document import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from smolagents import Tool
from langchain_community.retrievers import BM25Retriever
from smolagents import CodeAgent, InferenceClientModel

class PartyPlanningRetrieverTool(Tool):
    name = "party_planning_retriever"
    description = "Uses semantic search to retrieve relevant party planning ideas for Alfred’s superhero-themed party at Wayne Manor."
    inputs = {
        "query": {
            "type": "string",
            "description": "The query to perform. This should be a query related to party planning or superhero themes.",
        }
    }
    output_type = "string"

    def __init__(self, docs, **kwargs):
        super().__init__(**kwargs)
        self.retriever = BM25Retriever.from_documents(
            docs, k=5  # Retrieve the top 5 documents
        )

    def forward(self, query: str) -> str:
        assert isinstance(query, str), "Your search query must be a string"

        docs = self.retriever.invoke(
            query,
        )
        return "\nRetrieved ideas:\n" + "".join(
            [
                f"\n\n===== Idea {str(i)} =====\n" + doc.page_content
                for i, doc in enumerate(docs)
            ]
        )

# Simulate a knowledge base about party planning
party_ideas = [
    {"text": "A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.", "source": "Party Ideas 1"},
    {"text": "Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.", "source": "Entertainment Ideas"},
    {"text": "For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'", "source": "Catering Ideas"},
    {"text": "Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.", "source": "Decoration Ideas"},
    {"text": "Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.", "source": "Entertainment Ideas"}
]

source_docs = [
    Document(page_content=doc["text"], metadata={"source": doc["source"]})
    for doc in party_ideas
]

# Split the documents into smaller chunks for more efficient search
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    add_start_index=True,
    strip_whitespace=True,
    separators=["\n\n", "\n", ".", " ", ""],
)
docs_processed = text_splitter.split_documents(source_docs)

# Create the retriever tool
party_planning_retriever = PartyPlanningRetrieverTool(docs_processed)

# Initialize the agent
agent = CodeAgent(tools=[party_planning_retriever], model=InferenceClientModel())

# Example usage
response = agent.run(
    "Find ideas for a luxury superhero-themed party and including whom to invite."
)

print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Find ideas for a luxury superhero-themed party and including whom to invite.                                    │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   query = "luxury superhero-themed party ideas and guest list"
#   ideas = party_planning_retriever(query=query)
#   print(ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
#
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 2 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# Out: None
# [Step 1: Duration 9.56 seconds| Input tokens: 2,099 | Output tokens: 1,918]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   query = "luxury superhero-themed party guest list suggestions for Wayne Manor"
#   guest_list = party_planning_retriever(query=query)
#   print(guest_list)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
#
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# ===== Idea 2 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 3 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 4 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# Out: None
# [Step 2: Duration 6.94 seconds| Input tokens: 4,505 | Output tokens: 3,187]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("Batman, Superman, Wonder Woman, Green Lantern, Flash, and Commissioner Gordon")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Batman, Superman, Wonder Woman, Green Lantern, Flash, and Commissioner Gordon
# [Step 3: Duration 26.73 seconds| Input tokens: 7,206 | Output tokens: 8,356]
# Batman, Superman, Wonder Woman, Green Lantern, Flash, and Commissioner Gordon
